# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#%%capture
#!wget -N https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip
#!unzip -o /content/dogImages.zip
#!mv /content/dogImages /content/drive/My\ Drive/dog-breeds/dog_images

# %% [markdown]
# # Configuration & utilities
#
# Here we define the configuration parameters, dependencies and utility functions needed for the experiment. You may only need to specify the 'experiment_description' value in the first line of code, and the paths identifying the project and the different datasets.

# %%
import numpy as np
from glob import glob
import sys

experiment_description = 'architectures_comparision'
project_path = '/content/drive/My Drive/dog-breeds/'

##################### DO NOT MODIFY ################################

experiment_location = project_path + experiment_description
escaped_exp_location = experiment_location.replace(" ", "\\ ")
# !mkdir $escaped_exp_location
model_file = experiment_location + '/model_ ' + experiment_description
output_file = experiment_location + '/' + experiment_description
sys.path.append(project_path)
##################### END: DO NOT MODIFY ###########################

dog_files = np.array(glob(project_path + "dog_images/*/*/*"))
print('There are %d total dog images.' % len(dog_files))
train_path = project_path + 'dog_images/train'
validation_path = project_path +'dog_images/valid'
test_path = project_path +'dog_images/test'


def print_gpu():
  gpu_info = !nvidia-smi
  gpu_info = '\n'.join(gpu_info)
  if gpu_info.find('failed') >= 0:
    print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
  else:
    print(gpu_info)
# Out:
# mkdir: cannot create directory ‘/content/drive/My Drive/dog-breeds/architectures_comparision’: File exists
# There are 8351 total dog images.

# %% [markdown]
# # Experiment
#
# A lot of things here need to be separated:
#
#  - Creation of dataset loaders
#  - NN architecture
#  - Hyperparameter dictionaries
#  - Testing and Rebooting functions
#  - Experiment loop
#  - Visualization

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from utils.preprocess import *
from utils.resnet_model import *
from utils.train import *
from utils.simple_model import *
import torch.optim as optim
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

augmentations = [
                 [iaa.Resize((224, 224)), iaa.Crop(percent=(0, 0.45))]
                ]
learning_rates = [
                 0.001
                 ]
optimizers = [
             optim.Adam
             ]
models = [
         simple_cnn(),
         resnet18()
         ]
         
paths = {
    'train_path' : train_path,
    'validation_path' : validation_path,
    'test_path' : test_path
}


hyperparameters_dictionary = {
    'augmentations' : augmentations,
    'learning_rates' : learning_rates,
    'epochs' : 50,
    'optimizers' : optimizers,
    'models' : models
}

print_gpu()
run_experiments(paths, hyperparameters_dictionary, model_file)
# Out:
# Thu Apr 23 14:55:03 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    32W / 250W |  16215MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+
# cuda available
# running experiment with hyperparameters:
# augmentations: [Resize(name=UnnamedResize, parameters=[DiscreteUniform(Deterministic(int 224), Deterministic(int 224)), Deterministic(cubic)], deterministic=False), CropAndPad(name=UnnamedCrop, parameters=[Uniform(Deterministic(int 0), Deterministic(float -0.45000000)), None, None, None, None, Deterministic(constant), Deterministic(int 0)], deterministic=False)]
# model: Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=25088, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=133, bias=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
# optimizer: <class 'torch.optim.adam.Adam'>
# learning rate: 0.001
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Epoch: 1 	Training Loss: 6.394925 	Validation Loss: 4.783476 	Time spent: 85.963204
# Epoch: 2 	Training Loss: 4.705443 	Validation Loss: 4.697136 	Time spent: 84.802932
# Epoch: 3 	Training Loss: 4.594221 	Validation Loss: 4.565079 	Time spent: 84.313170
# Epoch: 4 	Training Loss: 4.504560 	Validation Loss: 4.503160 	Time spent: 84.305869
# Epoch: 5 	Training Loss: 4.476945 	Validation Loss: 4.510700 	Time spent: 84.999336
# Epoch: 6 	Training Loss: 4.463939 	Validation Loss: 4.499272 	Time spent: 84.164625
# Epoch: 7 	Training Loss: 4.423872 	Validation Loss: 4.446918 	Time spent: 83.802145
# Epoch: 8 	Training Loss: 4.396914 	Validation Loss: 4.402633 	Time spent: 84.121542
# Epoch: 9 	Training Loss: 4.353196 	Validation Loss: 4.354233 	Time spent: 84.597097
# Epoch: 10 	Training Loss: 4.323112 	Validation Loss: 4.285848 	Time spent: 84.707630
# Epoch: 11 	Training Loss: 4.309080 	Validation Loss: 4.318738 	Time spent: 84.044538
# Epoch: 12 	Training Loss: 4.260287 	Validation Loss: 4.294705 	Time spent: 83.804276
# Epoch: 13 	Training Loss: 4.231663 	Validation Loss: 4.195047 	Time spent: 83.807492
# Epoch: 14 	Training Loss: 4.200052 	Validation Loss: 4.415246 	Time spent: 83.680471
# Epoch: 15 	Training Loss: 4.215423 	Validation Loss: 4.338698 	Time spent: 83.453678
# Epoch: 16 	Training Loss: 4.203279 	Validation Loss: 4.137821 	Time spent: 83.461167
# Epoch: 17 	Training Loss: 4.175416 	Validation Loss: 4.172031 	Time spent: 83.932460
# Epoch: 18 	Training Loss: 4.137342 	Validation Loss: 4.342984 	Time spent: 83.399963
# Epoch: 19 	Training Loss: 4.139391 	Validation Loss: 4.184139 	Time spent: 83.383757
# Epoch: 20 	Training Loss: 4.116035 	Validation Loss: 4.147501 	Time spent: 83.267748
# Epoch: 21 	Training Loss: 4.081964 	Validation Loss: 4.063870 	Time spent: 83.506603
# Epoch: 22 	Training Loss: 4.094512 	Validation Loss: 4.177402 	Time spent: 83.673962
# Epoch: 23 	Training Loss: 4.093491 	Validation Loss: 4.089947 	Time spent: 83.637819
# Epoch: 24 	Training Loss: 4.058431 	Validation Loss: 4.108182 	Time spent: 84.352183
# Epoch: 25 	Training Loss: 4.033129 	Validation Loss: 4.131401 	Time spent: 84.057667
# Epoch: 26 	Training Loss: 4.025108 	Validation Loss: 4.202100 	Time spent: 83.885847
# Epoch: 27 	Training Loss: 4.006076 	Validation Loss: 4.087785 	Time spent: 83.849694
# Epoch: 28 	Training Loss: 3.993072 	Validation Loss: 4.015621 	Time spent: 84.222042
# Epoch: 29 	Training Loss: 3.949442 	Validation Loss: 4.260789 	Time spent: 84.135706
# Epoch: 30 	Training Loss: 3.953662 	Validation Loss: 4.077181 	Time spent: 83.483843
# Epoch: 31 	Training Loss: 3.936736 	Validation Loss: 4.028654 	Time spent: 83.873757
# Epoch: 32 	Training Loss: 3.920704 	Validation Loss: 4.006599 	Time spent: 84.147328
# Epoch: 33 	Training Loss: 3.908664 	Validation Loss: 3.971435 	Time spent: 84.452266
# Epoch: 34 	Training Loss: 3.883487 	Validation Loss: 3.988379 	Time spent: 83.429204
# Epoch: 35 	Training Loss: 3.869833 	Validation Loss: 4.080649 	Time spent: 83.709914
# Epoch: 36 	Training Loss: 3.871931 	Validation Loss: 4.064414 	Time spent: 83.882497
# Epoch: 37 	Training Loss: 3.865033 	Validation Loss: 3.998180 	Time spent: 83.394931
# Epoch: 38 	Training Loss: 3.836924 	Validation Loss: 3.913349 	Time spent: 83.506212
# Epoch: 39 	Training Loss: 3.829507 	Validation Loss: 4.041199 	Time spent: 84.049730
# Epoch: 40 	Training Loss: 3.819973 	Validation Loss: 3.937393 	Time spent: 83.839274
# Epoch: 41 	Training Loss: 3.818854 	Validation Loss: 3.983247 	Time spent: 83.171962
# Epoch: 42 	Training Loss: 3.768576 	Validation Loss: 3.880889 	Time spent: 83.626475
# Epoch: 43 	Training Loss: 3.787412 	Validation Loss: 4.136179 	Time spent: 83.905975
# Epoch: 44 	Training Loss: 3.778101 	Validation Loss: 4.265381 	Time spent: 83.467833
# Epoch: 45 	Training Loss: 3.761609 	Validation Loss: 4.053070 	Time spent: 83.187741
# Epoch: 46 	Training Loss: 3.745407 	Validation Loss: 4.073182 	Time spent: 82.817360
# Epoch: 47 	Training Loss: 3.730051 	Validation Loss: 3.982905 	Time spent: 86.184460
# Epoch: 48 	Training Loss: 3.737297 	Validation Loss: 4.222501 	Time spent: 84.367609
# Epoch: 49 	Training Loss: 3.729110 	Validation Loss: 4.118959 	Time spent: 83.485056
# Epoch: 50 	Training Loss: 3.688830 	Validation Loss: 3.998573 	Time spent: 83.754888
# time spent:  1:10:01.817051
# Minimum trainig loss:  3.6888303756713867
# Minimum validation loss:  3.8808889389038086
# Test Loss: 3.855291
#
# Test Accuracy: 13% (109/836)
#
#
# cuda available
# running experiment with hyperparameters:
# augmentations: [Resize(name=UnnamedResize, parameters=[DiscreteUniform(Deterministic(int 224), Deterministic(int 224)), Deterministic(cubic)], deterministic=False), CropAndPad(name=UnnamedCrop, parameters=[Uniform(Deterministic(int 0), Deterministic(float -0.45000000)), None, None, None, None, Deterministic(constant), Deterministic(int 0)], deterministic=False)]
# model: ResNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv3_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv4_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv5_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=133, bias=True)
# )
# optimizer: <class 'torch.optim.adam.Adam'>
# learning rate: 0.001
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Epoch: 1 	Training Loss: 4.751873 	Validation Loss: 4.901550 	Time spent: 129.551252
# Epoch: 2 	Training Loss: 4.519116 	Validation Loss: 4.730632 	Time spent: 128.903622
# Epoch: 3 	Training Loss: 4.427580 	Validation Loss: 4.793913 	Time spent: 130.345774
# Epoch: 4 	Training Loss: 4.363477 	Validation Loss: 4.692047 	Time spent: 129.027326
# Epoch: 5 	Training Loss: 4.326644 	Validation Loss: 4.554686 	Time spent: 129.170093
# Epoch: 6 	Training Loss: 4.270374 	Validation Loss: 4.575546 	Time spent: 130.105195
# Epoch: 7 	Training Loss: 4.221427 	Validation Loss: 4.586855 	Time spent: 129.485839
# Epoch: 8 	Training Loss: 4.152460 	Validation Loss: 4.573316 	Time spent: 129.216457
# Epoch: 9 	Training Loss: 4.089580 	Validation Loss: 4.703183 	Time spent: 129.839303
# Epoch: 10 	Training Loss: 4.014221 	Validation Loss: 4.472385 	Time spent: 129.605221
# Epoch: 11 	Training Loss: 3.957911 	Validation Loss: 4.202124 	Time spent: 128.427312
# Epoch: 12 	Training Loss: 3.908760 	Validation Loss: 4.465680 	Time spent: 130.015152
# Epoch: 13 	Training Loss: 3.830969 	Validation Loss: 4.678091 	Time spent: 128.767970
# Epoch: 14 	Training Loss: 3.787352 	Validation Loss: 4.470610 	Time spent: 129.803133
# Epoch: 15 	Training Loss: 3.748809 	Validation Loss: 4.415917 	Time spent: 128.778528
# Epoch: 16 	Training Loss: 3.704494 	Validation Loss: 4.356968 	Time spent: 128.780505
# Epoch: 17 	Training Loss: 3.673668 	Validation Loss: 4.644248 	Time spent: 129.373535
# Epoch: 18 	Training Loss: 3.626544 	Validation Loss: 4.193038 	Time spent: 129.818799
# Epoch: 19 	Training Loss: 3.591379 	Validation Loss: 4.216043 	Time spent: 130.893497
# Epoch: 20 	Training Loss: 3.536816 	Validation Loss: 3.997843 	Time spent: 130.213022
# Epoch: 21 	Training Loss: 3.499551 	Validation Loss: 3.837031 	Time spent: 129.276468
# Epoch: 22 	Training Loss: 3.474802 	Validation Loss: 4.112311 	Time spent: 129.764731
# Epoch: 23 	Training Loss: 3.418530 	Validation Loss: 3.945222 	Time spent: 129.645017
# Epoch: 24 	Training Loss: 3.389542 	Validation Loss: 3.910150 	Time spent: 128.910561
# Epoch: 25 	Training Loss: 3.364245 	Validation Loss: 3.812553 	Time spent: 128.844169
# Epoch: 26 	Training Loss: 3.338904 	Validation Loss: 4.409691 	Time spent: 129.712294
# Epoch: 27 	Training Loss: 3.299366 	Validation Loss: 3.935565 	Time spent: 130.022854
# Epoch: 28 	Training Loss: 3.243956 	Validation Loss: 4.139836 	Time spent: 129.633354
# Epoch: 29 	Training Loss: 3.234760 	Validation Loss: 3.788558 	Time spent: 128.837663
# Epoch: 30 	Training Loss: 3.206372 	Validation Loss: 4.101645 	Time spent: 128.997071
# Epoch: 31 	Training Loss: 3.201783 	Validation Loss: 3.929523 	Time spent: 129.121554
# Epoch: 32 	Training Loss: 3.142595 	Validation Loss: 3.732188 	Time spent: 130.171996
# Epoch: 33 	Training Loss: 3.099917 	Validation Loss: 3.758959 	Time spent: 130.084687
# Epoch: 34 	Training Loss: 3.073234 	Validation Loss: 3.850253 	Time spent: 129.038186
# Epoch: 35 	Training Loss: 3.034179 	Validation Loss: 3.794560 	Time spent: 129.236469
# Epoch: 36 	Training Loss: 2.996691 	Validation Loss: 3.793207 	Time spent: 129.543351
# Epoch: 37 	Training Loss: 2.996027 	Validation Loss: 3.654512 	Time spent: 129.580622
# Epoch: 38 	Training Loss: 2.946819 	Validation Loss: 3.777106 	Time spent: 128.889427
# Epoch: 39 	Training Loss: 2.918146 	Validation Loss: 3.630671 	Time spent: 129.202653
# Epoch: 40 	Training Loss: 2.874074 	Validation Loss: 3.590862 	Time spent: 129.381552
# Epoch: 41 	Training Loss: 2.828449 	Validation Loss: 3.540633 	Time spent: 129.710454
# Epoch: 42 	Training Loss: 2.817352 	Validation Loss: 3.605695 	Time spent: 128.872882
# Epoch: 43 	Training Loss: 2.770627 	Validation Loss: 3.527916 	Time spent: 130.004285
# Epoch: 44 	Training Loss: 2.696026 	Validation Loss: 3.564645 	Time spent: 129.517705
# Epoch: 45 	Training Loss: 2.692692 	Validation Loss: 3.527034 	Time spent: 129.808311
# Epoch: 46 	Training Loss: 2.649624 	Validation Loss: 3.522635 	Time spent: 129.230783
# Epoch: 47 	Training Loss: 2.639575 	Validation Loss: 3.510064 	Time spent: 128.434944
# Epoch: 48 	Training Loss: 2.590770 	Validation Loss: 3.609246 	Time spent: 129.598403
# Epoch: 49 	Training Loss: 2.540511 	Validation Loss: 3.426911 	Time spent: 128.445352
# Epoch: 50 	Training Loss: 2.516104 	Validation Loss: 3.479431 	Time spent: 129.052689
# time spent:  1:47:53.665735
# Minimum trainig loss:  2.5161044597625732
# Minimum validation loss:  3.426910877227783
# Test Loss: 3.230231
#
# Test Accuracy: 24% (203/836)
