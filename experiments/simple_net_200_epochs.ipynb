# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#%%capture
#!wget -N https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip
#!unzip -o /content/dogImages.zip
#!mv /content/dogImages /content/drive/My\ Drive/dog-breeds/dog_images

# %% [markdown]
# # Configuration & utilities
#
# Here we define the configuration parameters, dependencies and utility functions needed for the experiment. You may only need to specify the 'experiment_description' value in the first line of code, and the paths identifying the project and the different datasets.

# %%
import numpy as np
from glob import glob
import sys

experiment_description = 'simple_net_200_epochs'
project_path = '/content/drive/My Drive/dog-breeds/'

##################### DO NOT MODIFY ################################

experiment_location = project_path + experiment_description
escaped_exp_location = experiment_location.replace(" ", "\\ ")
# !mkdir $escaped_exp_location
model_file = experiment_location + '/model_ ' + experiment_description
output_file = experiment_location + '/' + experiment_description
sys.path.append(project_path)
##################### END: DO NOT MODIFY ###########################

dog_files = np.array(glob(project_path + "dog_images/*/*/*"))
print('There are %d total dog images.' % len(dog_files))
train_path = project_path + 'dog_images/train'
validation_path = project_path +'dog_images/valid'
test_path = project_path +'dog_images/test'


def print_gpu():
  gpu_info = !nvidia-smi
  gpu_info = '\n'.join(gpu_info)
  if gpu_info.find('failed') >= 0:
    print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
  else:
    print(gpu_info)
# Out:
# There are 8351 total dog images.

# %% [markdown]
# # Experiment
#
# A lot of things here need to be separated:
#
#  - Creation of dataset loaders
#  - NN architecture
#  - Hyperparameter dictionaries
#  - Testing and Rebooting functions
#  - Experiment loop
#  - Visualization

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from utils.preprocess import *
from utils.resnet_model import *
from utils.train import *
from utils.simple_model import *
import torch.optim as optim
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

augmentations = [
                 [iaa.Resize((224, 224)), iaa.Crop(percent=(0, 0.45))]
                ]
learning_rates = [
                 0.001
                 ]
optimizers = [
             optim.Adam
             ]
models = [
         simple_cnn()
         ]
         
paths = {
    'train_path' : train_path,
    'validation_path' : validation_path,
    'test_path' : test_path
}


hyperparameters_dictionary = {
    'augmentations' : augmentations,
    'learning_rates' : learning_rates,
    'epochs' : 200,
    'optimizers' : optimizers,
    'models' : models
}

print_gpu()
run_experiments(paths, hyperparameters_dictionary, model_file)
# Out:
# Thu Apr 23 19:10:55 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# cuda available
# running experiment with hyperparameters:
# augmentations: [Resize(name=UnnamedResize, parameters=[DiscreteUniform(Deterministic(int 224), Deterministic(int 224)), Deterministic(cubic)], deterministic=False), CropAndPad(name=UnnamedCrop, parameters=[Uniform(Deterministic(int 0), Deterministic(float -0.45000000)), None, None, None, None, Deterministic(constant), Deterministic(int 0)], deterministic=False)]
# model: Net(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=25088, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=133, bias=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )
# optimizer: <class 'torch.optim.adam.Adam'>
# learning rate: 0.001
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Epoch: 1 	Training Loss: 6.517961 	Validation Loss: 4.870572 	Time spent: 1110.477292
# Epoch: 2 	Training Loss: 4.805542 	Validation Loss: 4.734247 	Time spent: 102.454043
# Epoch: 3 	Training Loss: 4.629173 	Validation Loss: 4.612949 	Time spent: 101.718338
# Epoch: 4 	Training Loss: 4.576448 	Validation Loss: 4.574574 	Time spent: 102.214319
# Epoch: 5 	Training Loss: 4.514768 	Validation Loss: 4.481009 	Time spent: 102.202793
# Epoch: 137 	Training Loss: 2.962943 	Validation Loss: 3.146730 	Time spent: 103.475937
# Epoch: 138 	Training Loss: 2.939003 	Validation Loss: 3.280966 	Time spent: 103.555526
# Epoch: 139 	Training Loss: 2.944697 	Validation Loss: 3.362999 	Time spent: 102.110769
# Epoch: 140 	Training Loss: 2.945700 	Validation Loss: 3.252985 	Time spent: 102.295272
# Epoch: 141 	Training Loss: 2.920124 	Validation Loss: 3.322826 	Time spent: 102.083217
# Epoch: 142 	Training Loss: 2.945688 	Validation Loss: 3.270154 	Time spent: 101.526560
# Epoch: 143 	Training Loss: 2.925293 	Validation Loss: 3.267252 	Time spent: 100.739315
# Epoch: 144 	Training Loss: 2.923570 	Validation Loss: 3.245698 	Time spent: 101.060113
# Epoch: 145 	Training Loss: 2.916426 	Validation Loss: 3.462672 	Time spent: 100.581701
# Epoch: 146 	Training Loss: 2.929466 	Validation Loss: 3.371341 	Time spent: 100.648896
# Epoch: 147 	Training Loss: 2.909199 	Validation Loss: 3.329788 	Time spent: 101.011686
# Epoch: 148 	Training Loss: 2.892877 	Validation Loss: 3.235948 	Time spent: 100.186208
# Epoch: 149 	Training Loss: 2.912452 	Validation Loss: 3.196836 	Time spent: 100.347849
# Epoch: 150 	Training Loss: 2.904735 	Validation Loss: 3.213692 	Time spent: 100.044007
# Epoch: 151 	Training Loss: 2.894546 	Validation Loss: 3.306078 	Time spent: 99.751121
# Epoch: 152 	Training Loss: 2.890015 	Validation Loss: 3.406832 	Time spent: 99.770785
# Epoch: 153 	Training Loss: 2.870597 	Validation Loss: 3.263940 	Time spent: 99.482763
# Epoch: 154 	Training Loss: 2.878806 	Validation Loss: 3.208716 	Time spent: 98.925279
# Epoch: 155 	Training Loss: 2.860978 	Validation Loss: 3.281071 	Time spent: 101.185714
# Epoch: 156 	Training Loss: 2.879375 	Validation Loss: 3.203787 	Time spent: 100.681483
# Epoch: 157 	Training Loss: 2.854697 	Validation Loss: 3.196633 	Time spent: 99.177147
# Epoch: 158 	Training Loss: 2.857445 	Validation Loss: 3.186312 	Time spent: 98.889035
# Epoch: 159 	Training Loss: 2.845110 	Validation Loss: 3.216625 	Time spent: 99.321122
# Epoch: 160 	Training Loss: 2.831376 	Validation Loss: 3.436051 	Time spent: 98.662127
# Epoch: 161 	Training Loss: 2.844691 	Validation Loss: 3.237524 	Time spent: 98.327011
# Epoch: 162 	Training Loss: 2.849826 	Validation Loss: 3.274838 	Time spent: 98.832372
# Epoch: 163 	Training Loss: 2.821365 	Validation Loss: 3.307861 	Time spent: 98.525158
# Epoch: 164 	Training Loss: 2.833782 	Validation Loss: 3.286823 	Time spent: 98.351732
# Epoch: 165 	Training Loss: 2.818887 	Validation Loss: 3.304389 	Time spent: 98.821353
# Epoch: 166 	Training Loss: 2.806162 	Validation Loss: 3.216866 	Time spent: 98.080934
# Epoch: 167 	Training Loss: 2.794269 	Validation Loss: 3.245030 	Time spent: 98.716061
# Epoch: 168 	Training Loss: 2.802530 	Validation Loss: 3.267830 	Time spent: 98.945914
# Epoch: 169 	Training Loss: 2.790471 	Validation Loss: 3.157151 	Time spent: 98.286767
# Epoch: 170 	Training Loss: 2.795689 	Validation Loss: 3.335543 	Time spent: 97.950379
# Epoch: 171 	Training Loss: 2.792467 	Validation Loss: 3.192254 	Time spent: 97.930319
# Epoch: 172 	Training Loss: 2.790344 	Validation Loss: 3.227351 	Time spent: 97.412237
# Epoch: 173 	Training Loss: 2.785902 	Validation Loss: 3.267001 	Time spent: 98.051827
# Epoch: 174 	Training Loss: 2.801858 	Validation Loss: 3.198017 	Time spent: 97.579524
# Epoch: 175 	Training Loss: 2.770375 	Validation Loss: 3.127418 	Time spent: 98.490492
# Epoch: 176 	Training Loss: 2.764253 	Validation Loss: 3.164492 	Time spent: 100.478737
# Epoch: 177 	Training Loss: 2.791738 	Validation Loss: 3.382525 	Time spent: 98.783173
# Epoch: 178 	Training Loss: 2.750979 	Validation Loss: 3.295241 	Time spent: 97.881119
# Epoch: 179 	Training Loss: 2.769641 	Validation Loss: 3.248360 	Time spent: 97.625345
# Epoch: 180 	Training Loss: 2.750635 	Validation Loss: 3.145661 	Time spent: 98.282741
# Epoch: 181 	Training Loss: 2.748785 	Validation Loss: 3.205321 	Time spent: 98.570088
# Epoch: 182 	Training Loss: 2.743336 	Validation Loss: 3.269384 	Time spent: 97.976700
# Epoch: 183 	Training Loss: 2.724661 	Validation Loss: 3.157166 	Time spent: 98.021363
# Epoch: 184 	Training Loss: 2.731844 	Validation Loss: 3.300082 	Time spent: 97.833700
# Epoch: 185 	Training Loss: 2.731760 	Validation Loss: 3.136313 	Time spent: 97.980219
# Epoch: 186 	Training Loss: 2.726896 	Validation Loss: 3.288679 	Time spent: 97.725624
# Epoch: 187 	Training Loss: 2.699669 	Validation Loss: 3.269014 	Time spent: 97.359467
# Epoch: 188 	Training Loss: 2.722569 	Validation Loss: 3.150532 	Time spent: 97.368061
# Epoch: 189 	Training Loss: 2.726724 	Validation Loss: 3.336081 	Time spent: 97.116121
# Epoch: 190 	Training Loss: 2.703026 	Validation Loss: 3.349724 	Time spent: 96.963423
# Epoch: 191 	Training Loss: 2.695204 	Validation Loss: 3.276376 	Time spent: 96.695005
# Epoch: 192 	Training Loss: 2.694252 	Validation Loss: 3.195648 	Time spent: 97.353853
# Epoch: 193 	Training Loss: 2.699981 	Validation Loss: 3.367912 	Time spent: 97.088031
# Epoch: 194 	Training Loss: 2.666452 	Validation Loss: 3.195260 	Time spent: 97.660450
# Epoch: 195 	Training Loss: 2.662722 	Validation Loss: 3.440172 	Time spent: 97.181226
# Epoch: 196 	Training Loss: 2.671247 	Validation Loss: 3.163180 	Time spent: 97.908827
# Epoch: 197 	Training Loss: 2.668638 	Validation Loss: 3.258206 	Time spent: 98.422241
# Epoch: 198 	Training Loss: 2.642806 	Validation Loss: 3.321659 	Time spent: 98.023084
# Epoch: 199 	Training Loss: 2.661113 	Validation Loss: 3.136045 	Time spent: 97.895009
# Epoch: 200 	Training Loss: 2.664578 	Validation Loss: 3.151343 	Time spent: 97.977489
# time spent:  5:55:42.372529
# Minimum trainig loss:  2.642805814743042
# Minimum validation loss:  3.127417802810669
# Test Loss: 3.089080
#
# Test Accuracy: 25% (211/836)
