# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#%%capture
#!wget -N https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip
#!unzip -o /content/dogImages.zip
#!mv /content/dogImages /content/drive/My\ Drive/dog-breeds/dog_images

# %% [markdown]
# # Configuration & utilities
#
# Here we define the configuration parameters, dependencies and utility functions needed for the experiment. You may only need to specify the 'experiment_description' value in the first line of code, and the paths identifying the project and the different datasets.

# %%
import numpy as np
from glob import glob
import sys

experiment_description = 'optimizers_comparisons'
project_path = '/content/drive/My Drive/dog-breeds/'

##################### DO NOT MODIFY ################################

experiment_location = project_path + experiment_description
escaped_exp_location = experiment_location.replace(" ", "\\ ")
# !mkdir $escaped_exp_location
model_file = experiment_location + '/model_ ' + experiment_description
output_file = experiment_location + '/' + experiment_description
sys.path.append(project_path)
##################### END: DO NOT MODIFY ###########################

dog_files = np.array(glob(project_path + "dog_images/*/*/*"))
print('There are %d total dog images.' % len(dog_files))
train_path = project_path + 'dog_images/train'
validation_path = project_path +'dog_images/valid'
test_path = project_path +'dog_images/test'


def print_gpu():
  gpu_info = !nvidia-smi
  gpu_info = '\n'.join(gpu_info)
  if gpu_info.find('failed') >= 0:
    print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
  else:
    print(gpu_info)
# Out:
# There are 8351 total dog images.

# %% [markdown]
# # Experiment

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from utils.preprocess import *
from utils.resnet_model import *
from utils.train import *
from utils.simple_model import *
import torch.optim as optim
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

sometimes = lambda aug: iaa.Sometimes(0.5, aug)

augmentations = [
                 [iaa.Resize((224, 224)), 
                  sometimes(iaa.Crop(percent=(0, 0.45))),
                  iaa.Multiply((0.5, 1.5), per_channel=0.5),
                  iaa.Grayscale(alpha=(0.0, 1.0))]
                ]
learning_rates = [
                 0.0015
                 ]
optimizers = [
                optim.Adam, 
                optim.SGD, 
                optim.Adagrad
             ]
models = [
         resnet18()
         ]
         
paths = {
    'train_path' : train_path,
    'validation_path' : validation_path,
    'test_path' : test_path
}


hyperparameters_dictionary = {
    'augmentations' : augmentations,
    'learning_rates' : learning_rates,
    'epochs' : 50,
    'optimizers' : optimizers,
    'models' : models
}

print_gpu()
run_experiments(paths, hyperparameters_dictionary, model_file)
# Out:
# Sat Apr 25 17:26:38 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# cuda available
# running experiment with hyperparameters:
# augmentations: [Resize(name=UnnamedResize, parameters=[DiscreteUniform(Deterministic(int 224), Deterministic(int 224)), Deterministic(cubic)], deterministic=False), Sometimes(p=Binomial(Deterministic(float 0.50000000)), name=UnnamedSometimes, then_list=Sequential(name=UnnamedSometimes-then, random_order=False, children=[CropAndPad(name=UnnamedCrop, parameters=[Uniform(Deterministic(int 0), Deterministic(float -0.45000000)), None, None, None, None, Deterministic(constant), Deterministic(int 0)], deterministic=False)], deterministic=False), else_list=None, deterministic=False), Multiply(name=UnnamedMultiply, parameters=[Uniform(Deterministic(float 0.50000000), Deterministic(float 1.50000000)), Binomial(Deterministic(float 0.50000000))], deterministic=False), ChangeColorspace(name=UnnamedGrayscale, parameters=[Deterministic(GRAY), Uniform(Deterministic(float 0.00000000), Deterministic(float 1.00000000))], deterministic=False)]
# model: ResNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (con
# Epoch: 28 	Training Loss: 3.243145 	Validation Loss: 3.216504 	Time spent: 131.684664
# Epoch: 29 	Training Loss: 3.195451 	Validation Loss: 3.244297 	Time spent: 131.518811
# Epoch: 30 	Training Loss: 3.108082 	Validation Loss: 4.236590 	Time spent: 131.095105
# Epoch: 31 	Training Loss: 3.059046 	Validation Loss: 3.037844 	Time spent: 131.184289
# Epoch: 32 	Training Loss: 3.000031 	Validation Loss: 3.384831 	Time spent: 132.284254
# Epoch: 33 	Training Loss: 2.900549 	Validation Loss: 3.022072 	Time spent: 132.056304
# Epoch: 34 	Training Loss: 2.817184 	Validation Loss: 2.802255 	Time spent: 131.018533
# Epoch: 35 	Training Loss: 2.783543 	Validation Loss: 2.657608 	Time spent: 131.623530
# Epoch: 36 	Training Loss: 2.682428 	Validation Loss: 2.992814 	Time spent: 131.089280
# Epoch: 37 	Training Loss: 2.633637 	Validation Loss: 2.517811 	Time spent: 130.812082
# Epoch: 38 	Training Loss: 2.557053 	Validation Loss: 2.485820 	Time spent: 130.978854
# Epoch: 39 	Training Loss: 2.480327 	Validation Loss: 2.610975 	Time spent: 131.720322
# Epoch: 40 	Training Loss: 2.424001 	Validation Loss: 2.497907 	Time spent: 131.228599
# Epoch: 41 	Training Loss: 2.355942 	Validation Loss: 2.493950 	Time spent: 132.105987
# Epoch: 42 	Training Loss: 2.262745 	Validation Loss: 2.434214 	Time spent: 131.226969
# Epoch: 43 	Training Loss: 2.227654 	Validation Loss: 2.693010 	Time spent: 130.922494
# Epoch: 44 	Training Loss: 2.195263 	Validation Loss: 2.566729 	Time spent: 131.954771
# Epoch: 45 	Training Loss: 2.129924 	Validation Loss: 2.576104 	Time spent: 131.205121
# Epoch: 46 	Training Loss: 2.069623 	Validation Loss: 2.320926 	Time spent: 131.528659
# Epoch: 47 	Training Loss: 2.009844 	Validation Loss: 2.164093 	Time spent: 131.929549
# Epoch: 48 	Training Loss: 1.961323 	Validation Loss: 2.580174 	Time spent: 131.720201
# Epoch: 49 	Training Loss: 1.895278 	Validation Loss: 2.227077 	Time spent: 131.763945
# Epoch: 50 	Training Loss: 1.871862 	Validation Loss: 2.451920 	Time spent: 132.243640
# time spent:  2:06:17.231702
# Minimum trainig loss:  1.8718618154525757
# Minimum validation loss:  2.164093017578125
# Test Loss: 2.155369
#
# Test Accuracy: 41% (349/836)
#
#
# running experiment with hyperparameters:
# augmentations: [Resize(name=UnnamedResize, parameters=[DiscreteUniform(Deterministic(int 224), Deterministic(int 224)), Deterministic(cubic)], deterministic=False), Sometimes(p=Binomial(Deterministic(float 0.50000000)), name=UnnamedSometimes, then_list=Sequential(name=UnnamedSometimes-then, random_order=False, children=[CropAndPad(name=UnnamedCrop, parameters=[Uniform(Deterministic(int 0), Deterministic(float -0.45000000)), None, None, None, None, Deterministic(constant), Deterministic(int 0)], deterministic=False)], deterministic=False), else_list=None, deterministic=False), Multiply(name=UnnamedMultiply, parameters=[Uniform(Deterministic(float 0.50000000), Deterministic(float 1.50000000)), Binomial(Deterministic(float 0.50000000))], deterministic=False), ChangeColorspace(name=UnnamedGrayscale, parameters=[Deterministic(GRAY), Uniform(Deterministic(float 0.00000000), Deterministic(float 1.00000000))], deterministic=False)]
# model: ResNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv3_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv4_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv5_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=133, bias=True)
# )
# optimizer: <class 'torch.optim.sgd.SGD'>
# learning rate: 0.0015
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.0015
#     momentum: 0
#     nesterov: False
#     weight_decay: 0
# )
# Epoch: 1 	Training Loss: 5.343915 	Validation Loss: 5.497721 	Time spent: 131.303560
# Epoch: 2 	Training Loss: 4.998153 	Validation Loss: 5.515703 	Time spent: 131.179821
# Epoch: 3 	Training Loss: 4.916090 	Validation Loss: 5.439517 	Time spent: 130.013684
# Epoch: 4 	Training Loss: 4.863866 	Validation Loss: 5.329663 	Time spent: 131.516217
# Epoch: 5 	Training Loss: 4.841938 	Validation Loss: 5.225377 	Time spent: 130.185786
# Epoch: 6 	Training Loss: 4.817891 	Validation Loss: 5.114306 	Time spent: 131.004730
# Epoch: 7 	Training Loss: 4.786621 	Validation Loss: 4.962300 	Time spent: 130.476483
# Epoch: 8 	Training Loss: 4.780293 	Validation Loss: 4.910795 	Time spent: 130.948051
# Epoch: 9 	Training Loss: 4.756858 	Validation Loss: 4.893332 	Time spent: 130.832392
# Epoch: 10 	Training Loss: 4.736102 	Validation Loss: 5.308258 	Time spent: 131.784534
# Epoch: 11 	Training Loss: 4.731231 	Validation Loss: 4.918629 	Time spent: 130.009590
# Epoch: 12 	Training Loss: 4.724314 	Validation Loss: 4.995526 	Time spent: 130.373932
# Epoch: 13 	Training Loss: 4.700825 	Validation Loss: 4.973466 	Time spent: 131.022970
# Epoch: 14 	Training Loss: 4.682755 	Validation Loss: 4.757118 	Time spent: 130.482130
# Epoch: 15 	Training Loss: 4.678103 	Validation Loss: 4.918633 	Time spent: 131.211306
# Epoch: 16 	Training Loss: 4.673352 	Validation Loss: 4.702145 	Time spent: 131.131973
# Epoch: 17 	Training Loss: 4.655727 	Validation Loss: 4.865980 	Time spent: 131.224167
# Epoch: 18 	Training Loss: 4.640506 	Validation Loss: 4.688815 	Time spent: 130.942864
# Epoch: 19 	Training Loss: 4.620881 	Validation Loss: 4.654266 	Time spent: 130.615062
# Epoch: 20 	Training Loss: 4.616207 	Validation Loss: 5.020357 	Time spent: 131.566684
# Epoch: 21 	Training Loss: 4.600956 	Validation Loss: 4.841677 	Time spent: 132.607786
# Epoch: 22 	Training Loss: 4.586143 	Validation Loss: 4.649308 	Time spent: 131.030212
# Epoch: 23 	Training Loss: 4.587363 	Validation Loss: 4.560380 	Time spent: 131.517704
# Epoch: 24 	Training Loss: 4.568109 	Validation Loss: 4.715036 	Time spent: 130.857294
# augmentations: [Resize(name=UnnamedResize, parameters=[DiscreteUniform(Deterministic(int 224), Deterministic(int 224)), Deterministic(cubic)], deterministic=False), Sometimes(p=Binomial(Deterministic(float 0.50000000)), name=UnnamedSometimes, then_list=Sequential(name=UnnamedSometimes-then, random_order=False, children=[CropAndPad(name=UnnamedCrop, parameters=[Uniform(Deterministic(int 0), Deterministic(float -0.45000000)), None, None, None, None, Deterministic(constant), Deterministic(int 0)], deterministic=False)], deterministic=False), else_list=None, deterministic=False), Multiply(name=UnnamedMultiply, parameters=[Uniform(Deterministic(float 0.50000000), Deterministic(float 1.50000000)), Binomial(Deterministic(float 0.50000000))], deterministic=False), ChangeColorspace(name=UnnamedGrayscale, parameters=[Deterministic(GRAY), Uniform(Deterministic(float 0.00000000), Deterministic(float 1.00000000))], deterministic=False)]
# model: ResNet(
#   (conv1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (conv2_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv3_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv4_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (conv5_x): Sequential(
#     (0): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (residual_function): Sequential(
#         (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (shortcut): Sequential()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=133, bias=True)
# )
# optimizer: <class 'torch.optim.adagrad.Adagrad'>
# learning rate: 0.0015
# Adagrad (
# Parameter Group 0
#     eps: 1e-10
#     initial_accumulator_value: 0
#     lr: 0.0015
#     lr_decay: 0
#     weight_decay: 0
# )
# Epoch: 1 	Training Loss: 5.168994 	Validation Loss: 4.813970 	Time spent: 130.110997
# Epoch: 2 	Training Loss: 4.730268 	Validation Loss: 4.650783 	Time spent: 130.550008
# Epoch: 3 	Training Loss: 4.609007 	Validation Loss: 4.693628 	Time spent: 131.388896
# Epoch: 4 	Training Loss: 4.474857 	Validation Loss: 4.384525 	Time spent: 131.492495
# Epoch: 5 	Training Loss: 4.339775 	Validation Loss: 4.564211 	Time spent: 130.325039
# Epoch: 6 	Training Loss: 4.216584 	Validation Loss: 4.451336 	Time spent: 131.934507
# Epoch: 7 	Training Loss: 4.075783 	Validation Loss: 6.140232 	Time spent: 130.878492
# Epoch: 8 	Training Loss: 3.946309 	Validation Loss: 4.750388 	Time spent: 131.529996
# Epoch: 9 	Training Loss: 3.858330 	Validation Loss: 5.542089 	Time spent: 131.407491
# Epoch: 10 	Training Loss: 3.748265 	Validation Loss: 3.872921 	Time spent: 131.903007
# Epoch: 11 	Training Loss: 3.671114 	Validation Loss: 4.579404 	Time spent: 131.866242
# Epoch: 12 	Training Loss: 3.560062 	Validation Loss: 3.942622 	Time spent: 132.178708
# Epoch: 13 	Training Loss: 3.473524 	Validation Loss: 4.758989 	Time spent: 130.814367
# Epoch: 14 	Training Loss: 3.392301 	Validation Loss: 4.664381 	Time spent: 129.915914
# Epoch: 15 	Training Loss: 3.299374 	Validation Loss: 3.380324 	Time spent: 131.323949
# Epoch: 16 	Training Loss: 3.209915 	Validation Loss: 3.799752 	Time spent: 130.699167
# Epoch: 17 	Training Loss: 3.140171 	Validation Loss: 5.044301 	Time spent: 130.296800
# Epoch: 18 	Training Loss: 3.062972 	Validation Loss: 3.751828 	Time spent: 131.716437
# Epoch: 19 	Training Loss: 3.000183 	Validation Loss: 3.747184 	Time spent: 131.406309
# Epoch: 20 	Training Loss: 2.955172 	Validation Loss: 3.609588 	Time spent: 131.369436
# Epoch: 21 	Training Loss: 2.877712 	Validation Loss: 3.144971 	Time spent: 130.731075
# Epoch: 22 	Training Loss: 2.820288 	Validation Loss: 4.015552 	Time spent: 131.911203
