# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#%%capture
#!wget -N https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/dogImages.zip
#!unzip -o /content/dogImages.zip
#!mv /content/dogImages /content/drive/My\ Drive/dog-breeds/dog_images

# %% [markdown]
# # Configuration & utilities
#
# Here we define the configuration parameters, dependencies and utility functions needed for the experiment. You may only need to specify the 'experiment_description' value in the first line of code, and the paths identifying the project and the different datasets.

# %%
import numpy as np
from glob import glob
import sys

experiment_description = 'dropout_200_epochs'
project_path = '/content/drive/My Drive/dog-breeds/'

##################### DO NOT MODIFY ################################

experiment_location = project_path + experiment_description
escaped_exp_location = experiment_location.replace(" ", "\\ ")
# !mkdir $escaped_exp_location
model_file = experiment_location + '/model_ ' + experiment_description
output_file = experiment_location + '/' + experiment_description
sys.path.append(project_path)
##################### END: DO NOT MODIFY ###########################

dog_files = np.array(glob(project_path + "dog_images/*/*/*"))
print('There are %d total dog images.' % len(dog_files))
train_path = project_path + 'dog_images/train'
validation_path = project_path +'dog_images/valid'
test_path = project_path +'dog_images/test'


def print_gpu():
  gpu_info = !nvidia-smi
  gpu_info = '\n'.join(gpu_info)
  if gpu_info.find('failed') >= 0:
    print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
  else:
    print(gpu_info)
# Out:
# There are 8351 total dog images.

# %% [markdown]
# # Experiment
#
# A lot of things here need to be separated:
#
#  - Creation of dataset loaders
#  - NN architecture
#  - Hyperparameter dictionaries
#  - Testing and Rebooting functions
#  - Experiment loop
#  - Visualization

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from utils.preprocess import *
from utils.resnet_model import *
from utils.train import *
from utils.simple_model import *
from utils.simple_model_dropout import *
import torch.optim as optim
from PIL import ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

augmentations = [
                 [iaa.Resize((224, 224)), iaa.Crop(percent=(0, 0.45))]
                ]
learning_rates = [
                 0.001
                 ]
optimizers = [
             optim.Adam
             ]
models = [
         simple_cnn_dropout()
         ]
         
paths = {
    'train_path' : train_path,
    'validation_path' : validation_path,
    'test_path' : test_path
}


hyperparameters_dictionary = {
    'augmentations' : augmentations,
    'learning_rates' : learning_rates,
    'epochs' : 200,
    'optimizers' : optimizers,
    'models' : models
}

print_gpu()
run_experiments(paths, hyperparameters_dictionary, model_file)
# Out:
# Sat Apr 25 17:38:05 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# cuda available
# running experiment with hyperparameters:
# augmentations: [Resize(name=UnnamedResize, parameters=[DiscreteUniform(Deterministic(int 224), Deterministic(int 224)), Deterministic(cubic)], deterministic=False), CropAndPad(name=UnnamedCrop, parameters=[Uniform(Deterministic(int 0), Deterministic(float -0.45000000)), None, None, None, None, Deterministic(constant), Deterministic(int 0)], deterministic=False)]
# model: NetDropout(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (batchn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=25088, out_features=2048, bias=True)
#   (fc2): Linear(in_features=2048, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=133, bias=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.4, inplace=False)
# )
# optimizer: <class 'torch.optim.adam.Adam'>
# learning rate: 0.001
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# Epoch: 1 	Training Loss: 5.349720 	Validation Loss: 4.765131 	Time spent: 535.178050
# Epoch: 2 	Training Loss: 4.743795 	Validation Loss: 4.709492 	Time spent: 89.887436
# Epoch: 3 	Training Loss: 4.700755 	Validation Loss: 4.715704 	Time spent: 89.596561
# Epoch: 4 	Training Loss: 4.683832 	Validation Loss: 4.609842 	Time spent: 89.487512
# Epoch: 170 	Training Loss: 2.861026 	Validation Loss: 3.260641 	Time spent: 90.402759
# Epoch: 171 	Training Loss: 2.839259 	Validation Loss: 3.365848 	Time spent: 89.938308
# Epoch: 172 	Training Loss: 2.823679 	Validation Loss: 3.279727 	Time spent: 89.513323
# Epoch: 173 	Training Loss: 2.814030 	Validation Loss: 3.248523 	Time spent: 91.032748
# Epoch: 174 	Training Loss: 2.815617 	Validation Loss: 3.354547 	Time spent: 89.844049
# Epoch: 175 	Training Loss: 2.810016 	Validation Loss: 3.289464 	Time spent: 90.133592
# Epoch: 176 	Training Loss: 2.807482 	Validation Loss: 3.289168 	Time spent: 90.026204
# Epoch: 177 	Training Loss: 2.825336 	Validation Loss: 3.210474 	Time spent: 89.917940
# Epoch: 178 	Training Loss: 2.810029 	Validation Loss: 3.326419 	Time spent: 90.640727
# Epoch: 179 	Training Loss: 2.778421 	Validation Loss: 3.150007 	Time spent: 90.232216
# Epoch: 180 	Training Loss: 2.788764 	Validation Loss: 3.236757 	Time spent: 90.627848
# Epoch: 181 	Training Loss: 2.826256 	Validation Loss: 3.254276 	Time spent: 90.117533
# Epoch: 182 	Training Loss: 2.814357 	Validation Loss: 3.298976 	Time spent: 89.579887
# Epoch: 183 	Training Loss: 2.775612 	Validation Loss: 3.239186 	Time spent: 89.958785
# Epoch: 184 	Training Loss: 2.791833 	Validation Loss: 3.362607 	Time spent: 90.446526
# Epoch: 185 	Training Loss: 2.749424 	Validation Loss: 3.270654 	Time spent: 89.936933
# Epoch: 186 	Training Loss: 2.756851 	Validation Loss: 3.287713 	Time spent: 90.410950
# Epoch: 187 	Training Loss: 2.760734 	Validation Loss: 3.233866 	Time spent: 91.394926
# Epoch: 188 	Training Loss: 2.787406 	Validation Loss: 3.245423 	Time spent: 90.827996
# Epoch: 189 	Training Loss: 2.739887 	Validation Loss: 3.223834 	Time spent: 90.711686
# Epoch: 190 	Training Loss: 2.751899 	Validation Loss: 3.285267 	Time spent: 90.712542
# Epoch: 191 	Training Loss: 2.769391 	Validation Loss: 3.199710 	Time spent: 90.854256
# Epoch: 192 	Training Loss: 2.735219 	Validation Loss: 3.230186 	Time spent: 89.523936
# Epoch: 193 	Training Loss: 2.742796 	Validation Loss: 3.443911 	Time spent: 89.639713
# Epoch: 194 	Training Loss: 2.724069 	Validation Loss: 3.260123 	Time spent: 90.372156
# Epoch: 195 	Training Loss: 2.726821 	Validation Loss: 3.277916 	Time spent: 90.043541
# Epoch: 196 	Training Loss: 2.733107 	Validation Loss: 3.375885 	Time spent: 90.144552
# Epoch: 197 	Training Loss: 2.740819 	Validation Loss: 3.165465 	Time spent: 90.569578
# Epoch: 198 	Training Loss: 2.705329 	Validation Loss: 3.299490 	Time spent: 90.007817
# Epoch: 199 	Training Loss: 2.701129 	Validation Loss: 3.234323 	Time spent: 90.088593
# Epoch: 200 	Training Loss: 2.719832 	Validation Loss: 3.186375 	Time spent: 89.674657
# time spent:  5:09:09.264082
# Minimum trainig loss:  2.701129198074341
# Minimum validation loss:  3.150007486343384
# Test Loss: 3.052298
#
# Test Accuracy: 24% (203/836)
